# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# 'c:\\Users\\shafi\\OneDrive\\Documents\\GitHub\\Image_classification\\model\\dataset'

# %%
img=cv2.imread(r"C:\Users\shafi\OneDrive\Documents\GitHub\Image_classification\model\test_images\13.jpg")

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (168, 300)

# %%
plt.imshow (gray,cmap="gray")

# %% [markdown]
# ## Now will apply haarcascade technique to detect 2 eyes and face

# %%
face_cascade = cv2.CascadeClassifier(r'C:\Users\shafi\OneDrive\Documents\GitHub\Image_classification\model\opencv\haarcascades\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(r'C:\Users\shafi\OneDrive\Documents\GitHub\Image_classification\model\opencv\haarcascades\haarcascade_eye.xml')

# %%
faces = face_cascade.detectMultiScale(gray,1.5,3)

# %%
faces
# Out:
# array([[108,  13, 122, 122]])

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (108, 13, 122, 122)

# %%
faces_img = cv2.rectangle(img,(x,y,),(x+w,y+h),(255,0,0),2)
plt.imshow(faces_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img=cv2.rectangle(img,(x,y,),(x+w,y+h),(255,0,0),2)
    roi_gray= gray[y:y+h,x:x+w]
    roi_color=face_img[y:y+h,x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey,),(ex+ew,ey+eh),(255,0,0),2)

plt.figure()
plt.imshow(face_img,cmap="gray")
plt.show()

# %%
plt.imshow(roi_color,cmap="gray")

# %%
cropped_img=np.array(roi_color)
cropped_img.shape
# Out:
# (122, 122, 3)
